# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/data_v5.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Year  t1_general_traditional_WIN%  \
# 0             0           0  2001                         56.1
# 1             1           1  2001                         63.4
# 2             2           2  2001                         50.0
# 3             3           3  2001                         58.5
# 4             4           4  2001                         64.6
#
#    t1_general_traditional_PTS  t1_general_traditional_FGM  \
# 0                        91.9                        34.1
# 1                       100.7                        38.0
# 2                        92.6                        34.5
# 3                        88.7                        33.6
# 4                       100.5                        37.6
#
#    t1_general_traditional_FG%  t1_general_traditional_3PM  \
# 0                        43.1                         4.1
# 1                        45.8                         6.9
# ...

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1','Year','t1_TEAM','t2_TEAM','t1_series_wins','t2_series_wins'],inplace=True)

# %%
outcomes = df['outcome']
df = df.drop(columns=['outcome'])

# %%
cols = list(df.columns)
suffixes = []
for col in cols:
    if 't1' in col:
        suffixes.append(col[col.find('t1_')+3:])
    elif 't2' in col:
        suffixes.append(col[col.find('t2_')+3:])
    else:
        print(col)

# %%
suffixes
# Out:
# ['general_traditional_WIN%',
#  'general_traditional_PTS',
#  'general_traditional_FGM',
#  'general_traditional_FG%',
#  'general_traditional_3PM',
#  'general_traditional_3P%',
#  'general_traditional_FTM',
#  'general_traditional_FT%',
#  'general_traditional_OREB',
#  'general_traditional_DREB',
#  'general_traditional_REB',
#  'general_traditional_AST',
#  'general_traditional_TOV',
#  'general_traditional_STL',
#  'general_traditional_BLK',
#  'general_traditional_BLKA',
#  'general_traditional_PF',
#  'general_traditional_PFD',
#  'general_traditional_+/-',
#  'general_advanced_OffRtg',
#  'general_advanced_DefRtg',
#  'general_advanced_NetRtg',
#  'general_advanced_AST%',
#  'general_advanced_AST/TO',
#  'general_advanced_AST',
#  'general_advanced_OREB%',
#  'general_advanced_DREB%',
#  'general_advanced_REB%',
#  'general_advanced_TOV%',
#  'general_advanced_eFG%',
#  'general_advanced_TS%',
#  'general_advanced_PACE',
#  'general_advanced_PIE',
#  'general_advanced_POSS',
# ...

# %%
d = {}
for suf in suffixes:
    ar = np.subtract(df['t1_'+suf].to_numpy().reshape(-1), df['t2_'+suf].to_numpy())
    d[suf+'_diff'] = ar[:]
v6 = pd.DataFrame(d)

# %%
v6.head()
# Out:
#    general_traditional_WIN%_diff  general_traditional_PTS_diff  \
# 0                           -4.9                           3.0
# 1                           11.0                           3.2
# 2                          -18.3                          -2.1
# 3                            1.2                          -8.9
# 4                            0.0                           3.4
#
#    general_traditional_FGM_diff  general_traditional_FG%_diff  \
# 0                           1.2                           0.1
# 1                           1.3                           2.0
# 2                          -0.9                          -0.7
# 3                          -3.6                           0.7
# 4                           1.5                          -1.2
#
#    general_traditional_3PM_diff  general_traditional_3P%_diff  \
# 0                          -1.7                           0.1
# 1                           0.9                           1.5
# ...

# %%
v6['outcome']=outcomes

# %%
v6.head()
# Out:
#    general_traditional_WIN%_diff  general_traditional_PTS_diff  \
# 0                           -4.9                           3.0
# 1                           11.0                           3.2
# 2                          -18.3                          -2.1
# 3                            1.2                          -8.9
# 4                            0.0                           3.4
#
#    general_traditional_FGM_diff  general_traditional_FG%_diff  \
# 0                           1.2                           0.1
# 1                           1.3                           2.0
# 2                          -0.9                          -0.7
# 3                          -3.6                           0.7
# 4                           1.5                          -1.2
#
#    general_traditional_3PM_diff  general_traditional_3P%_diff  \
# 0                          -1.7                           0.1
# 1                           0.9                           1.5
# ...

# %%
v6.to_csv('data/data_v6.csv',index=False)
