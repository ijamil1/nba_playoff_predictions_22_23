# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import *

# %%
df = pd.read_csv('data/data_v5.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Year  t1_general_traditional_WIN%  \
# 0             0           0  2001                         56.1
# 1             1           1  2001                         63.4
# 2             2           2  2001                         50.0
# 3             3           3  2001                         58.5
# 4             4           4  2001                         64.6
#
#    t1_general_traditional_PTS  t1_general_traditional_FGM  \
# 0                        91.9                        34.1
# 1                       100.7                        38.0
# 2                        92.6                        34.5
# 3                        88.7                        33.6
# 4                       100.5                        37.6
#
#    t1_general_traditional_FG%  t1_general_traditional_3PM  \
# 0                        43.1                         4.1
# 1                        45.8                         6.9
# ...

# %%
df.drop(columns=['Unnamed: 0.1','Unnamed: 0','Year','t1_TEAM','t2_TEAM'],inplace=True)

# %%
X = df.drop(columns=['outcome']).to_numpy()
y = df['outcome'].to_numpy()
mi = mutual_info_classif(X,y)

# %%
k_best = SelectKBest(mutual_info_classif,k=25).fit(X,y)

# %%
k_best

# %%
selected_fts = k_best.get_feature_names_out(list(df.columns).remove('outcome'))

# %%
fts_list = []
for s in selected_fts:
    fts_list.append(int(s[1:]))

# %%
subset_df = df.iloc[:,fts_list]

# %%
subset_df['outcome']=y

# %%
subset_df.head()

# %%
subset_df.to_csv('data/data_v6_k25.csv')
